# %%
print('Hello, world!')
# Out:
# Hello, world!

# %%
print(1+2)
# Out:
# 3

# %%
#import os
#cwd =os.getcwd()

import pandas as pd

df = pd.read_csv("file:///C:/Users/kwasi/Documents/Python%20for%20Analytics/ChallengerSales_Wk5_Ex_data.csv", sep=",")

# %%
df
# Out:
#        Date  Day       Time  Gender BuyCategory  ItemsOrdered  TotalCost  \
# 0     6-Mar  Mon    Morning  Female        High             4     136.97
# 1     6-Mar  Mon    Morning  Female      Medium             1      25.55
# 2     6-Mar  Mon  Afternoon  Female      Medium             5     113.95
# 3     6-Mar  Mon  Afternoon  Female         Low             1       6.82
# 4     6-Mar  Mon  Afternoon    Male      Medium             4     147.32
# ..      ...  ...        ...     ...         ...           ...        ...
# 395  25-Jun  Sat  Afternoon    Male      Medium             6     268.39
# 396  25-Jun  Sat  Afternoon  Female      Medium             3     169.11
# 397  25-Jun  Sat  Afternoon    Male      Medium             6     242.46
# 398  25-Jun  Sat  Afternoon    Male      Medium             4     168.64
# 399  25-Jun  Sat  Afternoon  Female         Low             1     107.59
#
#      HighItem Member Region
# 0       79.97    Yes   West
# 1       25.55     No   West
# ...

# %%
df.shape
# Out:
# (400, 10)

# %%
df.size
# Out:
# 4000

# %%
df.dtypes
# Out:
# Date             object
# Day              object
# Time             object
# Gender           object
# BuyCategory      object
# ItemsOrdered      int64
# TotalCost       float64
# HighItem        float64
# Member           object
# Region           object
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of        Date  Day       Time  Gender BuyCategory  ItemsOrdered  TotalCost  \
# 0     6-Mar  Mon    Morning  Female        High             4     136.97
# 1     6-Mar  Mon    Morning  Female      Medium             1      25.55
# 2     6-Mar  Mon  Afternoon  Female      Medium             5     113.95
# 3     6-Mar  Mon  Afternoon  Female         Low             1       6.82
# 4     6-Mar  Mon  Afternoon    Male      Medium             4     147.32
# ..      ...  ...        ...     ...         ...           ...        ...
# 395  25-Jun  Sat  Afternoon    Male      Medium             6     268.39
# 396  25-Jun  Sat  Afternoon  Female      Medium             3     169.11
# 397  25-Jun  Sat  Afternoon    Male      Medium             6     242.46
# 398  25-Jun  Sat  Afternoon    Male      Medium             4     168.64
# 399  25-Jun  Sat  Afternoon  Female         Low             1     107.59
#
#      HighItem Member Region
# 0       79.97    Yes   West
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Time', 'Gender', 'BuyCategory', 'ItemsOrdered',
#        'TotalCost', 'HighItem', 'Member', 'Region'],
#       dtype='object')

# %%
df.values
# Out:
# array([['6-Mar', 'Mon', 'Morning', ..., 79.97, 'Yes', 'West'],
#        ['6-Mar', 'Mon', 'Morning', ..., 25.55, 'No', 'West'],
#        ['6-Mar', 'Mon', 'Afternoon', ..., 90.47, 'Yes', 'West'],
#        ...,
#        ['25-Jun', 'Sat', 'Afternoon', ..., 180.66, 'No', 'West'],
#        ['25-Jun', 'Sat', 'Afternoon', ..., 85.79, 'No', 'East'],
#        ['25-Jun', 'Sat', 'Afternoon', ..., 107.59, 'No', 'East']],
#       dtype=object)

# %%
 df.describe()
# Out:
#        ItemsOrdered   TotalCost    HighItem
# count    400.000000  400.000000  400.000000
# mean       3.467500  153.818025  100.442625
# std        2.022169   97.373038   67.051120
# min        1.000000    6.820000    6.820000
# 25%        2.000000   83.322500   56.222500
# 50%        3.000000  126.720000   83.395000
# 75%        4.000000  205.245000  119.440000
# max       11.000000  485.010000  381.330000

# %%
df
cols = ["ItemsOrdered", "TotalCost" , "HighItem"]
df[cols]
# Out:
#      ItemsOrdered  TotalCost  HighItem
# 0               4     136.97     79.97
# 1               1      25.55     25.55
# 2               5     113.95     90.47
# 3               1       6.82      6.82
# 4               4     147.32     83.21
# ..            ...        ...       ...
# 395             6     268.39    170.13
# 396             3     169.11     80.08
# 397             6     242.46    180.66
# 398             4     168.64     85.79
# 399             1     107.59    107.59
#
# [400 rows x 3 columns]

# %%
df
# Out:
#        Date  Day       Time  Gender BuyCategory  ItemsOrdered  TotalCost  \
# 0     6-Mar  Mon    Morning  Female        High             4     136.97
# 1     6-Mar  Mon    Morning  Female      Medium             1      25.55
# 2     6-Mar  Mon  Afternoon  Female      Medium             5     113.95
# 3     6-Mar  Mon  Afternoon  Female         Low             1       6.82
# 4     6-Mar  Mon  Afternoon    Male      Medium             4     147.32
# ..      ...  ...        ...     ...         ...           ...        ...
# 395  25-Jun  Sat  Afternoon    Male      Medium             6     268.39
# 396  25-Jun  Sat  Afternoon  Female      Medium             3     169.11
# 397  25-Jun  Sat  Afternoon    Male      Medium             6     242.46
# 398  25-Jun  Sat  Afternoon    Male      Medium             4     168.64
# 399  25-Jun  Sat  Afternoon  Female         Low             1     107.59
#
#      HighItem Member Region
# 0       79.97    Yes   West
# 1       25.55     No   West
# ...

# %%
df["ItemsOrdered"]
# Out:
# 0      4
# 1      1
# 2      5
# 3      1
# 4      4
#       ..
# 395    6
# 396    3
# 397    6
# 398    4
# 399    1
# Name: ItemsOrdered, Length: 400, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("file:///C:/Users/kwasi/Documents/Python%20for%20Analytics/ChallengerSales_Wk5_Ex_data.csv", sep=",")

df["ItemsOrdered"]
# Out:
# 0      4
# 1      1
# 2      5
# 3      1
# 4      4
#       ..
# 395    6
# 396    3
# 397    6
# 398    4
# 399    1
# Name: ItemsOrdered, Length: 400, dtype: int64

# %%
cols = ["ItemsOrdered", "TotalCost"]
df[cols]
# Out:
#      ItemsOrdered  TotalCost
# 0               4     136.97
# 1               1      25.55
# 2               5     113.95
# 3               1       6.82
# 4               4     147.32
# ..            ...        ...
# 395             6     268.39
# 396             3     169.11
# 397             6     242.46
# 398             4     168.64
# 399             1     107.59
#
# [400 rows x 2 columns]

# %%
df
cols = ["ItemsOrdered", "TotalCost", "HighItem"]
df(cols)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [39], in <cell line: 3>()
#       1 df
#       2 cols = ["ItemsOrdered", "TotalCost", "HighItem"]
# ----> 3 df(cols)
#
# TypeError: 'DataFrame' object is not callable

# %%
import pandas as pd
df = pd.read_csv("file:///C:/Users/kwasi/Documents/Python%20for%20Analytics/ChallengerSales_Wk5_Ex_data.csv"
df.loc["ItemsOrdered"][199]
# Out:
#   Input In [34]
#     df.loc["ItemsOrdered"][199]
#     ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

df = pd.read_csv("file:///C:/Users/kwasi/Documents/Python%20for%20Analytics/ChallengerSales_Wk5_Ex_data.csv", sep=",")

df["ItemsOrdered"][199]
# Out:
# 2

# %%
import pandas as pd

df = pd.read_csv("file:///C:/Users/kwasi/Documents/Python%20for%20Analytics/ChallengerSales_Wk5_Ex_data.csv")

df.loc[199]
# Out:
# Date              2-May
# Day                 Sat
# Time            Evening
# Gender           Female
# BuyCategory         Low
# ItemsOrdered          2
# TotalCost         85.31
# HighItem          66.83
# Member               No
# Region             West
# Name: 199, dtype: object

# %%
df.loc[:, ["ItemsOrdered", "TotalCost"]]
# Out:
#      ItemsOrdered  TotalCost
# 0               4     136.97
# 1               1      25.55
# 2               5     113.95
# 3               1       6.82
# 4               4     147.32
# ..            ...        ...
# 395             6     268.39
# 396             3     169.11
# 397             6     242.46
# 398             4     168.64
# 399             1     107.59
#
# [400 rows x 2 columns]

# %%
df.loc[:,:"TotalCost"].head(10)
# Out:
#     Date   Day       Time  Gender BuyCategory  ItemsOrdered  TotalCost
# 0  6-Mar   Mon    Morning  Female        High             4     136.97
# 1  6-Mar   Mon    Morning  Female      Medium             1      25.55
# 2  6-Mar   Mon  Afternoon  Female      Medium             5     113.95
# 3  6-Mar   Mon  Afternoon  Female         Low             1       6.82
# 4  6-Mar   Mon  Afternoon    Male      Medium             4     147.32
# 5  6-Mar   Mon  Afternoon  Female      Medium             5     142.15
# 6  7-Mar  Tues    Evening    Male         Low             1      18.65
# 7  7-Mar  Tues    Evening    Male        High             4     178.34
# 8  7-Mar  Tues    Evening    Male         Low             2      25.83
# 9  8-Mar   Wed    Morning  Female         Low             1      18.13

# %%
df.iloc[2:,6:]
# Out:
#      TotalCost  HighItem Member Region
# 2       113.95     90.47    Yes   West
# 3         6.82      6.82     No   East
# 4       147.32     83.21    Yes   West
# 5       142.15     50.90     No   East
# 6        18.65     18.65     No   West
# ..         ...       ...    ...    ...
# 395     268.39    170.13     No   East
# 396     169.11     80.08     No   East
# 397     242.46    180.66     No   West
# 398     168.64     85.79     No   East
# 399     107.59    107.59     No   East
#
# [398 rows x 4 columns]

# %% [markdown]
#  df.iloc[2:, 6:]

# %%
df.iloc[[0,2], [1,3]]
# Out:
#    Day  Gender
# 0  Mon  Female
# 2  Mon  Female

# %%
df.iloc[1:3, 2:7]
# Out:
#         Time  Gender BuyCategory  ItemsOrdered  TotalCost
# 1    Morning  Female      Medium             1      25.55
# 2  Afternoon  Female      Medium             5     113.95

# %%
# dataframe
import numpy as np
import pandas as pd
myarray = np.array([[1, 2, 3], [4, 5, 6]])
rownames = ['a', 'b']
colnames = ['one', 'two', 'three']
mydataframe = pd.DataFrame(myarray, index=rownames, columns=colnames)
print(mydataframe)
# Out:
#    one  two  three
# a    1    2      3
# b    4    5      6

# %%
import pandas as pd

df = pd.read_csv("file:///C:/Users/kwasi/Documents/Python%20for%20Analytics/ChallengerSales_Wk5_Ex_data.csv", sep=",")
df
# Out:
#        Date  Day       Time  Gender BuyCategory  ItemsOrdered  TotalCost  \
# 0     6-Mar  Mon    Morning  Female        High             4     136.97
# 1     6-Mar  Mon    Morning  Female      Medium             1      25.55
# 2     6-Mar  Mon  Afternoon  Female      Medium             5     113.95
# 3     6-Mar  Mon  Afternoon  Female         Low             1       6.82
# 4     6-Mar  Mon  Afternoon    Male      Medium             4     147.32
# ..      ...  ...        ...     ...         ...           ...        ...
# 395  25-Jun  Sat  Afternoon    Male      Medium             6     268.39
# 396  25-Jun  Sat  Afternoon  Female      Medium             3     169.11
# 397  25-Jun  Sat  Afternoon    Male      Medium             6     242.46
# 398  25-Jun  Sat  Afternoon    Male      Medium             4     168.64
# 399  25-Jun  Sat  Afternoon  Female         Low             1     107.59
#
#      HighItem Member Region
# 0       79.97    Yes   West
# 1       25.55     No   West
# ...
