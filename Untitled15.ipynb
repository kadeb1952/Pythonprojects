# %%
import pandas as pd

df = pd.read_csv("file:///C:/Users/kwasi/Documents/Python%20for%20Analytics/EDdata_new.csv")

# %%
df
# Out:
#          Case Hospital_Name  REGIS_DATE REGIS_TIME  reg_sec Triage Time  \
# 0       92408          KTPH    7/4/2012    9:48:33    35313     9:58:12
# 1       54452           KKH   7/10/2011   16:21:05    58865    16:23:42
# 2       28303           CGH   3/10/2011    3:57:45    14265     4:00:00
# 3      121169           SGH  16/10/2011    4:08:47    14927     4:10:00
# 4      146488          TTSH  24/10/2011    3:09:47    11387     3:14:21
# ...       ...           ...         ...        ...      ...         ...
# 41827   38592           CGH  29/10/2011   14:07:15    50835    14:17:00
# 41828   20523            AH   2/10/2011    7:18:06    26286     7:18:00
# 41829   30317           CGH   8/10/2011   12:59:42    46782    12:59:00
# 41830  126705           SGH  31/10/2011    9:55:18    35718    10:06:00
# 41831  110904           NUH   11/4/2012   11:20:27    40827    12:11:00
#
#        triage_sec Triage_Class    Age Gender     Race
# ...

# %%
df.shape
df["Hospital_Name"]
# Out:
# 0        KTPH
# 1         KKH
# 2         CGH
# 3         SGH
# 4        TTSH
#          ...
# 41827     CGH
# 41828      AH
# 41829     CGH
# 41830     SGH
# 41831     NUH
# Name: Hospital_Name, Length: 41832, dtype: object

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("file:///C:/Users/kwasi/Documents/Python%20for%20Analytics/EDdata_new.csv")

hosp_name = df["Hospital_Name"].unique()
print(hosp_name)
fil_2 = (df["Gender"] == "M") & (df["Hospital_Name"] != "KKH") 
df_female = df.loc[fil_2,:].copy() # subset data to meet the filtering condition
#print(df_female)
#out_table2 = {} # Create an empty dictionary 
#for hos in hosp_name:
df_female = df_female["Hospital_Name"].value_counts(normalize =True) 
    
print(df_female)    
###    out_table2.update({str(hos): list()})
#    for hos in hosp_name:
 #       filter_hos = (df_female["Hospital_Name"] == hos)
  #      df_temp = df_female.loc[filter_hos,:]
#out_table2[hos] = filter_hos.sum()
#print(out_table2)
#result2 = pd.Series(out_table2)
#result2/result2.sum()###
# Out:
# ['KTPH' 'KKH' 'CGH' 'SGH' 'TTSH' 'AH' 'NUH']
# TTSH    0.215002
# CGH     0.211559
# KTPH    0.191146
# SGH     0.168962
# NUH     0.142843
# AH      0.070487
# Name: Hospital_Name, dtype: float64

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("file:///C:/Users/kwasi/Documents/Python%20for%20Analytics/EDdata_new.csv")

df["REGIS_DAY"] = df.iloc[:3] #.astype(int)
df["REGIS_HOUR"] = df["REGIS_HOUR"].astype(int)
data_3124 = np.zeros((31,24), dtype = float)

for i in range(31):
    for j in range(24):
        number = ((df.REGIS_DAY== (i+1)) & (df.REGIS_HOUR == j))
        data_3124[i,j] = number.sum()
data_3124
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'REGIS_DAY'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("file:///C:/Users/kwasi/Documents/Python%20for%20Analytics/EDdata_new.csv")

df["wait_time"] = 0
n_pat = len(df)
df_reg = df["reg_sec"]
df_tri = df["triage_sec"]
df_wait = df["wait_time"]
df_wait = (24*60*60) + df_tri - df_reg
filt_1 = df["triage_sec"] > df["reg_sec"]
df_wait[filt_1] = df_tri[filt_1] - df_reg[filt_1]
df["wait_time"] = df_wait
df["wait_min"] = df_wait/60

# %%
df.head()
# Out:
#      Case Hospital_Name  REGIS_DATE REGIS_TIME  reg_sec Triage Time  \
# 0   92408          KTPH    7/4/2012    9:48:33    35313     9:58:12
# 1   54452           KKH   7/10/2011   16:21:05    58865    16:23:42
# 2   28303           CGH   3/10/2011    3:57:45    14265     4:00:00
# 3  121169           SGH  16/10/2011    4:08:47    14927     4:10:00
# 4  146488          TTSH  24/10/2011    3:09:47    11387     3:14:21
#
#    triage_sec Triage_Class    Age Gender     Race  wait_time  wait_min
# 0       35892            P2  40.0      M  Chinese        579  9.650000
# 1       59022            P2   0.0      M  Chinese        157  2.616667
# 2       14400            P3  33.0      M   Indian        135  2.250000
# 3       15000            P3  53.0      F    Malay         73  1.216667
# 4       11661            P3  23.0      M   Others        274  4.566667

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("file:///C:/Users/kwasi/Documents/Python%20for%20Analytics/EDdata_new.csv")

df.head()
df = df["REGIS_TIME"]


#Report_Card.loc[:,"Grades"]
Regis_Hours =  df["REGIS_TIME"].str.split(":", expand=True).str(0) 
Regis_Days = df["REGIS_DATE"].str.split("/").str(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 11>()
#       7 df = df["REGIS_TIME"]
#      10 #Report_Card.loc[:,"Grades"]
# ---> 11 Regis_Hours =  df["REGIS_TIME"].str.split(":", expand=True).str(0)
#      12 Regis_Days = df["REGIS_DATE"].str.split("/").str(0)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
# ...
