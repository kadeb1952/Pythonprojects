# %%
import numpy as np
#print("I have entered here")
distr = np.array([[0.315, 0.226, 0.289, 0.087, 0.083],
[560, 530, 389, 202, 278],
[533, 486, 386, 234, 263]])

order = np.array([430, 380])

prob = distr[0]
demand = distr[1:]
exp_d = prob*demand
diff = demand - order.reshape(2,1)
print(diff)


print(prob)
print(distr[1:])

exp_d_t =  np.sum(prob * demand, axis=2)
print(exp_d_t)



def sold_fun(order, distr):
    cost1 = 0.6
    cost2 = 0.8
    price1 = 1.0
    price2 = 1.15
    
    d1 = np.array(arr1)   #  create an array of order
    d2 = np.array(arr2)    # create an array of Probability and the two demands
    
    
    prob = d2[0]     # demand probabilities
    demand1 = d2[1]  # Expected demand1     
    demand2 = d2[2]  # Expexted demand2
    
    ord1 = d1[0]      # order quantity 1    
    ord2 = d1[1]     # order quantity 2
    
    diff1 = d1 - arr1[0]
    diff2 = d2 - arr1[1]
    diff1_n = diff1[2::]
    diff1_p = diff1[:2]
    
    r_diff1_p = np.reshape(diff1_p,-1)
    print(r_diff1_p)
     
    print(diff1)
    print(diff1_n)
    print(diff1_p)
    
    exp_sold1 = sum(diff1_n.shape*demand1+ r_diff1_p.shape*demand2)
    exp_sold2 = sum( diff2_n.shape*demand2 +r_diff_p.shape*demand1)
    print(exp_sold1)   
    print(exp_sold2)
    
    exp_profit1 = exp_sold1*price1 - arr1[0]*cost1
    exp_profit2 = exp_sold2*price2 - arr1[1]*cost2
    exp_total_profit = exp_profit1 + exp_profit2
    return exp_total_profit

   
exp_total_profit = sold_fun(order,distr)

print("The Expected Total Profit is: ${0:0.3f}".format(exp_total_profit))
# Out:
# [[ 130.  100.  -41. -228. -152.]
#  [ 153.  106.    6. -146. -117.]]
# [0.315 0.226 0.289 0.087 0.083]
# [[560. 530. 389. 202. 278.]
#  [533. 486. 386. 234. 263.]]
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 19>()
#      16 print(prob)
#      17 print(distr[1:])
# ---> 19 exp_d_t =  np.sum(prob * demand, axis=2)
#      20 print(exp_d_t)
#      24 def sold_fun(order, distr):
#
# File <__array_function__ internals>:5, in sum(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2259, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2256         return out
#    2257     return res
# -> 2259 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2260                       initial=initial, where=where)
#
# ...

# %%
sold_fun(arr1, arr2)  # call function with parameters

# %%
help(np.sum)
# Out:
# Help on function sum in module numpy:
#
# sum(a, axis=None, dtype=None, out=None, keepdims=<no value>, initial=<no value>, where=<no value>)
#     Sum of array elements over a given axis.
#
#     Parameters
#     ----------
#     a : array_like
#         Elements to sum.
#     axis : None or int or tuple of ints, optional
#         Axis or axes along which a sum is performed.  The default,
#         axis=None, will sum all of the elements of the input array.  If
#         axis is negative it counts from the last to the first axis.
#
#         .. versionadded:: 1.7.0
#
#         If axis is a tuple of ints, a sum is performed on all of the axes
#         specified in the tuple instead of a single axis or all the axes as
#         before.
#     dtype : dtype, optional
#         The type of the returned array and of the accumulator in which the
#         elements are summed.  The dtype of `a` is used by default unless `a`
# ...
